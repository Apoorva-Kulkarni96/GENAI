# %% [markdown]
# ### Running Ollama Locally with OpenAI Compatibile Endpoints

# %%
import requests

requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
from openai import OpenAI

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url = OLLAMA_BASE_URL, api_key = "ollama")

# %%
request = ollama.chat.completions.create(model="gemma:2b", messages=[{"role":"system","content":"You are useful assistant"},{"role": "user", "content": "Tell me a Fun Fact"}])

# %%
print(request.choices[0].message.content)
# Out:
# Sure. Here's a fun fact:
#
# Did you know that the world's smallest mammal is the bumblebee bat mouse? It's only about the size of a pinhead!
